# %%
import requests

url = "https://npi-lookup1.p.rapidapi.com/api"
my_key = "e7331fa4bbmshc279250a9989644p1ef5bdjsn4264af0807c7"
querystring = {"number":"1093873788","version":"2.1"}

headers = {
	"x-rapidapi-key": my_key,
	"x-rapidapi-host": "npi-lookup1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'result_count': 1, 'results': [{'addresses': [{'address_1': '1120 W WARNER AV', 'address_2': '#A', 'address_purpose': 'MAILING', 'address_type': 'DOM', 'city': 'SANTA ANA', 'country_code': 'US', 'country_name': 'United States', 'fax_number': '714-444-9892', 'postal_code': '92707', 'state': 'CA', 'telephone_number': '714-444-4448'}, {'address_1': '1120 W WARNER AV', 'address_2': '#A', 'address_purpose': 'LOCATION', 'address_type': 'DOM', 'city': 'SANTA ANA', 'country_code': 'US', 'country_name': 'United States', 'fax_number': '714-444-9892', 'postal_code': '92707', 'state': 'CA', 'telephone_number': '714-444-4448'}], 'basic': {'authorized_official_credential': 'MD', 'authorized_official_first_name': 'GHANSHYAM', 'authorized_official_last_name': 'LOHIYA', 'authorized_official_name_prefix': '--', 'authorized_official_name_suffix': '--', 'authorized_official_telephone_number': '7144444448', 'authorized_official_title_or_position': 'Owner', 'enumeration_date': '2006-12-05', 'last_updated
# ...

# %%
from pprint import pprint
pprint(response.json())
# Out:
# {'result_count': 1,
#  'results': [{'addresses': [{'address_1': '1120 W WARNER AV',
#                              'address_2': '#A',
#                              'address_purpose': 'MAILING',
#                              'address_type': 'DOM',
#                              'city': 'SANTA ANA',
#                              'country_code': 'US',
#                              'country_name': 'United States',
#                              'fax_number': '714-444-9892',
#                              'postal_code': '92707',
#                              'state': 'CA',
#                              'telephone_number': '714-444-4448'},
#                             {'address_1': '1120 W WARNER AV',
#                              'address_2': '#A',
#                              'address_purpose': 'LOCATION',
#                              'address_type': 'DOM',
#                              'city': 'SANTA ANA',
#                              'country_code': 'US',
# ...
